# %%
import IPython.display as ipd
ipd.Audio(filename="my/cloning/audio.wav")
# ipd.Audio(filename="yue/my/cloning/easy-man.wav")
# ipd.Audio(filename="yue/my/cloning/in-tts.wav")
# ipd.Audio(filename="yue/my/cloning/me-en.wav")
# ipd.Audio(filename="yue/my/cloning/me-zh.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
ipd.Audio(filename="output/easyman2.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
ipd.Audio(filename="output/intts2.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
ipd.Audio(filename="output/ljspeech6.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
ipd.Audio(filename="../tests/data/ljspeech/wavs/LJ001-0009.wav")
ipd.Audio(filename="../tests/data/ljspeech/wavs/LJ001-0010.wav")
# ipd.Audio(filename="../tests/data/ljspeech/wavs/LJ001-0030.wav")
# ipd.Audio(filename="../tests/data/ljspeech/wavs/LJ001-0031.wav")
# ipd.Audio(filename="../tests/data/ljspeech/wavs/LJ001-0032.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# list(f'./tests/data/ljspeech/wavs/LJ001-00{x}.wav' for x in range(1, 33))
# list(range(0,10))
l = list(str(x) for x in range(0,8))
l.clear()
l.extend([1,2,3])
print(l)
# Out:
# [1, 2, 3]
